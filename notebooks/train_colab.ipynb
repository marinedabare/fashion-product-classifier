# %% [markdown]
# # E-Commerce Vision Classifier — Training Notebook
#
# This notebook trains 3 models and generates evaluation results.
#
# **Before running:** Go to Runtime → Change runtime type → GPU

# %%
# Step 1: Clone the project (replace YOUR_USERNAME with your Hugging Face username)
# !git clone https://huggingface.co/spaces/YOUR_USERNAME/ecommerce-vision-classifier
# %cd ecommerce-vision-classifier

# %%
# Step 2: Install dependencies
# !pip install -q -r requirements.txt

# %%
# Step 3: Train all three models
# Downloads 1000 fashion images per category (Shoes, Watches, Sunglasses, Jeans)
# then trains: from-scratch CNN, pretrained frozen, pretrained fine-tuned
# !python -m src.train

# %%
# Step 4: Evaluate and compare all three models
# !python -m src.evaluate

# %%
# Step 5: View the comparison chart
from IPython.display import Image, display
display(Image(filename='outputs/model_comparison.png'))

# %%
# Step 6: View confusion matrices
from IPython.display import Image, display
import glob
for path in sorted(glob.glob('outputs/cm_*.png')):
    print(path)
    display(Image(filename=path))

# %%
# Step 7: Push to Hugging Face (replace YOUR_USERNAME, YOUR_EMAIL, and YOUR_TOKEN)
# !git config user.email "YOUR_EMAIL"
# !git config user.name "YOUR_USERNAME"
# !git remote set-url origin https://YOUR_USERNAME:YOUR_TOKEN@huggingface.co/spaces/YOUR_USERNAME/ecommerce-vision-classifier
# !git lfs install
# !git lfs track "*.keras"
# !git rm --cached outputs/*.keras 2>/dev/null; true
# !git add .gitattributes outputs/
# !git status

# %%
# Step 8: Commit and push
# !git commit -m "Retrain with data augmentation"
# !git push
